# %%
# %reset

# %%
import multiprocessing
import numpy as np
from heterogeneous_spatial_networks_funcs import filepath_str

# %%
# # This may or may not correspond to the number of cpus for optimal
# # parallelization performance. Feel free to modify if you see fit.
# cpu_num = int(np.floor(multiprocessing.cpu_count()/2))

# # Initialization of identification information for this particular batch
# # of spider web-inspired Delaunay-triangulated networks
# date = "20240626"
# batch = "A"
# network = "swidt"
# scheme = "rccs"

# elastically_effective = True

# # l_edges_variants
# l_edges = "l_edges"
# l_edges_x_cmpnt = "l_edges_x_cmpnt"
# l_edges_y_cmpnt = "l_edges_y_cmpnt"
# l_edges_z_cmpnt = "l_edges_z_cmpnt"
# l_nrmlzd_edges = "l_nrmlzd_edges"
# l_nrmlzd_edges_x_cmpnt = "l_nrmlzd_edges_x_cmpnt"
# l_nrmlzd_edges_y_cmpnt = "l_nrmlzd_edges_y_cmpnt"
# l_nrmlzd_edges_z_cmpnt = "l_nrmlzd_edges_z_cmpnt"

# dim_str = "dim"
# b_str = "b"
# n_str = "n"
# k_str = "k"
# rho_n_str = "rho_n"
# config_str = "config"
# pruning_str = "pruning"

# filepath = filepath_str(network)
# filename_prefix = filepath + f"{date}{batch}"

# identifier_filename = filename_prefix + "-identifier" + ".txt"
# dim_filename = filename_prefix + f"-{dim_str}" + ".dat"
# b_filename = filename_prefix + f"-{b_str}" + ".dat"
# n_filename = filename_prefix + f"-{n_str}" + ".dat"
# k_filename = filename_prefix + f"-{k_str}" + ".dat"
# rho_n_filename = filename_prefix + f"-{rho_n_str}" + ".dat"
# config_filename = filename_prefix + f"-{config_str}" + ".dat"
# pruning_filename = filename_prefix + f"-{pruning_str}" + ".dat"
# params_filename = filename_prefix + "-params" + ".dat"
# sample_params_filename = (
#     filename_prefix + "-sample_params" + ".dat"
# )

# identifier_arr = np.loadtxt(identifier_filename, dtype=str, usecols=0)
# dim_arr = np.loadtxt(dim_filename, dtype=int)
# b_arr = np.loadtxt(b_filename)
# n_arr = np.loadtxt(n_filename, dtype=int)
# k_arr = np.loadtxt(k_filename, dtype=int)
# rho_n_arr = np.loadtxt(rho_n_filename)
# config_arr = np.loadtxt(config_filename, dtype=int)
# pruning_arr = np.loadtxt(pruning_filename, dtype=int)
# params_arr = np.loadtxt(params_filename)
# sample_params_arr = np.loadtxt(sample_params_filename)

# b = b_arr

# %%
# This may or may not correspond to the number of cpus for optimal
# parallelization performance. Feel free to modify if you see fit.
cpu_num = int(np.floor(multiprocessing.cpu_count()/2))

# Initialization of identification information for this particular batch
# of spider web-inspired Delaunay-triangulated networks
date = "20240828"
batch = "A"
network = "swidt"
scheme = "rccs"

elastically_effective = True

# l_edges_variants
l_edges = "l_edges"
l_x_cmpnt_edges = "l_x_cmpnt_edges"
l_y_cmpnt_edges = "l_y_cmpnt_edges"
l_z_cmpnt_edges = "l_z_cmpnt_edges"
l_nrmlzd_edges = "l_nrmlzd_edges"
l_x_cmpnt_nrmlzd_edges = "l_x_cmpnt_nrmlzd_edges"
l_y_cmpnt_nrmlzd_edges = "l_y_cmpnt_nrmlzd_edges"
l_z_cmpnt_nrmlzd_edges = "l_z_cmpnt_nrmlzd_edges"

dim_str = "dim"
b_str = "b"
n_str = "n"
k_str = "k"
eta_n_str = "eta_n"
config_str = "config"
pruning_str = "pruning"

filepath = filepath_str(network)
filename_prefix = filepath + f"{date}{batch}"

identifier_filename = filename_prefix + "-identifier" + ".txt"
dim_filename = filename_prefix + f"-{dim_str}" + ".dat"
b_filename = filename_prefix + f"-{b_str}" + ".dat"
n_filename = filename_prefix + f"-{n_str}" + ".dat"
k_filename = filename_prefix + f"-{k_str}" + ".dat"
eta_n_filename = filename_prefix + f"-{eta_n_str}" + ".dat"
config_filename = filename_prefix + f"-{config_str}" + ".dat"
pruning_filename = filename_prefix + f"-{pruning_str}" + ".dat"
params_filename = filename_prefix + "-params" + ".dat"
sample_params_filename = (
    filename_prefix + "-sample_params" + ".dat"
)

identifier_arr = np.loadtxt(identifier_filename, dtype=str, usecols=0)
dim_arr = np.loadtxt(dim_filename, dtype=int)
b_arr = np.loadtxt(b_filename)
n_arr = np.loadtxt(n_filename, dtype=int)
k_arr = np.loadtxt(k_filename, dtype=int)
eta_n_arr = np.loadtxt(eta_n_filename)
config_arr = np.loadtxt(config_filename, dtype=int)
pruning_arr = np.loadtxt(pruning_filename, dtype=int)
params_arr = np.loadtxt(params_filename)
sample_params_arr = np.loadtxt(sample_params_filename)

b = b_arr

# %%
# Density histogram of the nodal degree for each swidt sample
from heterogeneous_spatial_networks_worker import run_swidt_graph_k_density_histogram_plotter

k_dnstyhist_min = 0.0
k_dnstyhist_max = 0.6
k_dnstyhist_inc = 0.1


k_dnstyhist_params_arr = (
    sample_params_arr[:, [0, 1, 3, 4, 5]]
) # sample, dim, n, k, eta_n
k_dnstyhist_params_list = list(map(tuple, k_dnstyhist_params_arr))


k_dnstyhist_params_args = (
    [
        (k_dnstyhist_min, k_dnstyhist_max, k_dnstyhist_inc, network, date, batch, int(sample), int(dim), int(n), int(k), eta_n, config_arr, pruning_arr, elastically_effective)
        for (sample, dim, n, k, eta_n) in k_dnstyhist_params_list
    ]
)

__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    pool.map(run_swidt_graph_k_density_histogram_plotter, k_dnstyhist_params_args)

# %%
# # Density histogram of chordless cycles for each swidt sample
# from heterogeneous_spatial_networks_worker import run_swidt_graph_h_density_histogram_plotter

# h_dnstyhist_min = 0.0
# h_dnstyhist_max = 0.8
# h_dnstyhist_inc = 0.1


# h_dnstyhist_params_arr = (
#     sample_params_arr[:, [0, 1, 3, 4, 5, 4]]
# ) # sample, dim, n, k, eta_n, k
# # k -> l_bound
# for sample in range(np.shape(h_dnstyhist_params_arr)[0]):
#     if h_dnstyhist_params_arr[sample, -1] == 3:
#         h_dnstyhist_params_arr[sample, -1] = 25
#     elif h_dnstyhist_params_arr[sample, -1] == 4:
#         h_dnstyhist_params_arr[sample, -1] = 15
#     elif h_dnstyhist_params_arr[sample, -1] == 5:
#         h_dnstyhist_params_arr[sample, -1] = 14
#     elif h_dnstyhist_params_arr[sample, -1] == 6:
#         h_dnstyhist_params_arr[sample, -1] = 12
#     elif h_dnstyhist_params_arr[sample, -1] == 7:
#         h_dnstyhist_params_arr[sample, -1] = 10
#     elif h_dnstyhist_params_arr[sample, -1] == 8:
#         h_dnstyhist_params_arr[sample, -1] = 10
# h_dnstyhist_params_list = list(map(tuple, h_dnstyhist_params_arr))


# h_dnstyhist_params_args = (
#     [
#         (h_dnstyhist_min, h_dnstyhist_max, h_dnstyhist_inc, network, date, batch, int(sample), int(dim), int(n), int(k), eta_n, int(l_bound), config_arr, pruning_arr)
#         for (sample, dim, n, k, eta_n, l_bound) in h_dnstyhist_params_list
#     ]
# )


# __spec__ = None
# with multiprocessing.Pool(processes=cpu_num) as pool:
#     pool.map(run_swidt_graph_h_density_histogram_plotter, h_dnstyhist_params_args)

# %%
# Density histogram of the edge length variants for each swidt sample
from heterogeneous_spatial_networks_worker import run_swidt_graph_l_edges_variant_density_histogram_plotter

l_nrmlzd_edges_first_bin = 0.0
l_nrmlzd_edges_last_bin = 0.3
l_nrmlzd_edges_bin_inc = 0.01
l_nrmlzd_edges_dnstyhist_min = 0.0
l_nrmlzd_edges_dnstyhist_max = 40.0
l_nrmlzd_edges_dnstyhist_inc = 5.0


l_edges_vrnt_dnstyhist_params_arr = (
    sample_params_arr[:, [0, 1, 3, 4, 5]]
) # sample, dim, n, k, eta_n
l_edges_vrnt_dnstyhist_params_list = list(map(tuple, l_edges_vrnt_dnstyhist_params_arr))


l_edges_dnstyhist_params_args = (
    [
        (l_nrmlzd_edges_first_bin, l_nrmlzd_edges_last_bin, l_nrmlzd_edges_bin_inc, l_nrmlzd_edges_dnstyhist_min, l_nrmlzd_edges_dnstyhist_max, l_nrmlzd_edges_dnstyhist_inc, network, date, batch, int(sample), int(dim), int(n), int(k), eta_n, config_arr, pruning_arr, elastically_effective, l_nrmlzd_edges)
        for (sample, dim, n, k, eta_n) in l_edges_vrnt_dnstyhist_params_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    pool.map(run_swidt_graph_l_edges_variant_density_histogram_plotter, l_edges_dnstyhist_params_args)

# %%
# Christmas tree plots of the nodal degree for each swidt sample
from heterogeneous_spatial_networks_worker import run_swidt_graph_k_christmas_tree_plot_plotter

k_min = 0.0
k_max = 9.0
k_inc = 1.0


k_xmastreeplt_params_arr = params_arr[:, [0, 1, 2, 4]] # dim, b, n, eta_n
k_xmastreeplt_params_arr = np.unique(k_xmastreeplt_params_arr, axis=0)
k_xmastreeplt_unique_samples_num = np.shape(k_xmastreeplt_params_arr)[0]
k_xmastreeplt_unique_samples_dim_2_arr = (
    np.arange(k_xmastreeplt_unique_samples_num).reshape((k_xmastreeplt_unique_samples_num, 1))
)
k_xmastreeplt_params_arr = np.concatenate(
    (k_xmastreeplt_unique_samples_dim_2_arr, k_xmastreeplt_params_arr),
    axis=1)
k_xmastreeplt_params_list = list(map(tuple, k_xmastreeplt_params_arr))


k_xmastreeplt_params_args = (
    [
        (k_min, k_max, k_inc, network, date, batch, int(unique_sample), int(dim), b, int(n), eta_n, k_arr, params_arr, config_arr, pruning_arr, elastically_effective)
        for (unique_sample, dim, b, n, eta_n) in k_xmastreeplt_params_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    pool.map(run_swidt_graph_k_christmas_tree_plot_plotter, k_xmastreeplt_params_args)

# %%
# Christmas tree plots of the nodal degree for each dimension
from heterogeneous_spatial_networks_worker import run_swidt_graph_k_dim_christmas_tree_plot_plotter

k_min = 0.0
k_max = 9.0
k_inc = 1.0


dim_list = dim_arr.tolist()


k_dim_xmastreeplt_params_args = (
    [
        (k_min, k_max, k_inc, network, date, batch, int(dim), b, n_arr, eta_n_arr, k_arr, params_arr, config_arr, pruning_arr, elastically_effective)
        for dim in dim_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    pool.map(run_swidt_graph_k_dim_christmas_tree_plot_plotter, k_dim_xmastreeplt_params_args)

# %%
# Plots displaying attributes of the statistical distribution of the
# nodal degree for each dimension
from heterogeneous_spatial_networks_worker import run_swidt_graph_k_dim_dist_stats_plotter

# For future cases, one may need to make multiple sets of such
# preformatting parameters, one for each variant and graph type
k_min = 0.0
k_max = 9.0
k_inc = 1.0


dim_list = dim_arr.tolist()


k_dim_dist_stats_plt_params_args = (
    [
        (k_min, k_max, k_inc, network, date, batch, int(dim), b, n_arr, eta_n_arr, k_arr, params_arr, config_arr, pruning_arr, elastically_effective)
        for dim in dim_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    pool.map(run_swidt_graph_k_dim_dist_stats_plotter, k_dim_dist_stats_plt_params_args)

# %%
# # Christmas tree plots of chordless cycles for each swidt sample
# from heterogeneous_spatial_networks_worker import run_swidt_graph_h_christmas_tree_plot_plotter

# h_xmastreeplt_params_arr = params_arr[:, [0, 1, 2, 4]] # dim, b, n, eta_n
# h_xmastreeplt_params_arr = np.unique(h_xmastreeplt_params_arr, axis=0)
# h_xmastreeplt_unique_samples_num = np.shape(h_xmastreeplt_params_arr)[0]
# h_xmastreeplt_unique_samples_dim_2_arr = (
#     np.arange(h_xmastreeplt_unique_samples_num).reshape((h_xmastreeplt_unique_samples_num, 1))
# )
# h_xmastreeplt_params_arr = np.concatenate(
#     (h_xmastreeplt_unique_samples_dim_2_arr, h_xmastreeplt_params_arr),
#     axis=1)
# h_xmastreeplt_params_list = list(map(tuple, h_xmastreeplt_params_arr))


# h_xmastreeplt_params_args = (
#     [
#         (network, date, batch, int(unique_sample), int(dim), b, int(n), eta_n, k_arr, params_arr, config_arr, pruning_arr)
#         for (unique_sample, dim, b, n, eta_n) in h_xmastreeplt_params_list
#     ]
# )


# __spec__ = None
# with multiprocessing.Pool(processes=cpu_num) as pool:
#     pool.map(run_swidt_graph_h_christmas_tree_plot_plotter, h_xmastreeplt_params_args)

# %%
# # Christmas tree plots of chordless cycles for each dimension
# from heterogeneous_spatial_networks_worker import run_swidt_graph_h_dim_christmas_tree_plot_plotter

# dim_list = dim_arr.tolist()


# h_dim_xmastreeplt_params_args = (
#     [
#         (network, date, batch, int(dim), b, n_arr, eta_n_arr, k_arr, params_arr, config_arr, pruning_arr)
#         for dim in dim_list
#     ]
# )


# __spec__ = None
# with multiprocessing.Pool(processes=cpu_num) as pool:
#     pool.map(run_swidt_graph_h_dim_christmas_tree_plot_plotter, h_dim_xmastreeplt_params_args)

# %%
# # Plots displaying attributes of the statistical distribution of
# # chordless cycles for each dimension
# from heterogeneous_spatial_networks_worker import run_swidt_graph_h_dim_dist_stats_plotter

# dim_list = dim_arr.tolist()


# h_dim_dist_stats_plt_params_args = (
#     [
#         (network, date, batch, int(dim), b, n_arr, eta_n_arr, k_arr, params_arr, config_arr, pruning_arr)
#         for dim in dim_list
#     ]
# )


# __spec__ = None
# with multiprocessing.Pool(processes=cpu_num) as pool:
#     pool.map(run_swidt_graph_h_dim_dist_stats_plotter, h_dim_dist_stats_plt_params_args)

# %%
# Violinplots for the core_pb and core_pb_conn edge length variants for
# each swidt sample
from heterogeneous_spatial_networks_worker import run_swidt_graph_l_edges_variant_violinplot_plotter

# For future cases, one may need to make multiple sets of such
# preformatting parameters, one for each variant and graph type
l_edges_min = 0.0
l_edges_max = 25.0
l_edges_inc = 5.0

l_x_cmpnt_edges_min = -l_edges_max
l_x_cmpnt_edges_max = l_edges_max
l_x_cmpnt_edges_inc = l_edges_inc

l_y_cmpnt_edges_min = -l_edges_max
l_y_cmpnt_edges_max = l_edges_max
l_y_cmpnt_edges_inc = l_edges_inc

l_z_cmpnt_edges_min = -l_edges_max
l_z_cmpnt_edges_max = l_edges_max
l_z_cmpnt_edges_inc = l_edges_inc

l_nrmlzd_edges_min = 0.0
l_nrmlzd_edges_max = 0.4
l_nrmlzd_edges_inc = 0.1

l_x_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_y_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_z_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc


l_edges_vrnt_vlnplt_params_arr = params_arr[:, [0, 1, 3, 4]] # dim, b, k, eta_n
l_edges_vrnt_vlnplt_params_arr = np.unique(l_edges_vrnt_vlnplt_params_arr, axis=0)
l_edges_vrnt_vlnplt_unique_samples_num = np.shape(l_edges_vrnt_vlnplt_params_arr)[0]
l_edges_vrnt_vlnplt_unique_samples_dim_2_arr = (
    np.arange(l_edges_vrnt_vlnplt_unique_samples_num).reshape((l_edges_vrnt_vlnplt_unique_samples_num, 1))
)
l_edges_vrnt_vlnplt_params_arr = np.concatenate(
    (l_edges_vrnt_vlnplt_unique_samples_dim_2_arr, l_edges_vrnt_vlnplt_params_arr),
    axis=1)
l_edges_vrnt_vlnplt_params_list = list(map(tuple, l_edges_vrnt_vlnplt_params_arr))


l_edges_vlnplt_params_args = (
    [
        (l_edges_min, l_edges_max, l_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_x_cmpnt_edges_vlnplt_params_args = (
    [
        (l_x_cmpnt_edges_min, l_x_cmpnt_edges_max, l_x_cmpnt_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_y_cmpnt_edges_vlnplt_params_args = (
    [
        (l_y_cmpnt_edges_min, l_y_cmpnt_edges_max, l_y_cmpnt_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_z_cmpnt_edges_vlnplt_params_args = (
    [
        (l_z_cmpnt_edges_min, l_z_cmpnt_edges_max, l_z_cmpnt_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)

l_nrmlzd_edges_vlnplt_params_args = (
    [
        (l_nrmlzd_edges_min, l_nrmlzd_edges_max, l_nrmlzd_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_nrmlzd_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_x_cmpnt_nrmlzd_edges_vlnplt_params_args = (
    [
        (l_x_cmpnt_nrmlzd_edges_min, l_x_cmpnt_nrmlzd_edges_max, l_x_cmpnt_nrmlzd_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_nrmlzd_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_y_cmpnt_nrmlzd_edges_vlnplt_params_args = (
    [
        (l_y_cmpnt_nrmlzd_edges_min, l_y_cmpnt_nrmlzd_edges_max, l_y_cmpnt_nrmlzd_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_nrmlzd_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)
l_z_cmpnt_nrmlzd_edges_vlnplt_params_args = (
    [
        (l_z_cmpnt_nrmlzd_edges_min, l_z_cmpnt_nrmlzd_edges_max, l_z_cmpnt_nrmlzd_edges_inc, network, date, batch, int(unique_sample), int(dim), b, int(k), eta_n, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_nrmlzd_edges)
        for (unique_sample, dim, b, k, eta_n) in l_edges_vrnt_vlnplt_params_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_edges_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_x_cmpnt_edges_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_y_cmpnt_edges_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_z_cmpnt_edges_vlnplt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_nrmlzd_edges_vlnplt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_x_cmpnt_nrmlzd_edges_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_y_cmpnt_nrmlzd_edges_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_violinplot_plotter, l_z_cmpnt_nrmlzd_edges_vlnplt_params_args)

# %%
# Violinplots for the core_pb and core_pb_conn edge length variants for
# each dimension
from heterogeneous_spatial_networks_worker import run_swidt_graph_l_edges_variant_dim_violinplot_plotter

# For future cases, one may need to make multiple sets of such
# preformatting parameters, one for each variant and graph type
l_edges_min = 0.0
l_edges_max = 25.0
l_edges_inc = 5.0

l_x_cmpnt_edges_min = -l_edges_max
l_x_cmpnt_edges_max = l_edges_max
l_x_cmpnt_edges_inc = l_edges_inc

l_y_cmpnt_edges_min = -l_edges_max
l_y_cmpnt_edges_max = l_edges_max
l_y_cmpnt_edges_inc = l_edges_inc

l_z_cmpnt_edges_min = -l_edges_max
l_z_cmpnt_edges_max = l_edges_max
l_z_cmpnt_edges_inc = l_edges_inc

l_nrmlzd_edges_min = 0.0
l_nrmlzd_edges_max = 0.4
l_nrmlzd_edges_inc = 0.1

l_x_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_y_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_z_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc


dim_list = dim_arr.tolist()


l_edges_dim_vlnplt_params_args = (
    [
        (l_edges_min, l_edges_max, l_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_edges)
        for dim in dim_list
    ]
)
l_x_cmpnt_edges_dim_vlnplt_params_args = (
    [
        (l_x_cmpnt_edges_min, l_x_cmpnt_edges_max, l_x_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_edges)
        for dim in dim_list
    ]
)
l_y_cmpnt_edges_dim_vlnplt_params_args = (
    [
        (l_y_cmpnt_edges_min, l_y_cmpnt_edges_max, l_y_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_edges)
        for dim in dim_list
    ]
)
l_z_cmpnt_edges_dim_vlnplt_params_args = (
    [
        (l_z_cmpnt_edges_min, l_z_cmpnt_edges_max, l_z_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_edges)
        for dim in dim_list
    ]
)

l_nrmlzd_edges_dim_vlnplt_params_args = (
    [
        (l_nrmlzd_edges_min, l_nrmlzd_edges_max, l_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_x_cmpnt_nrmlzd_edges_dim_vlnplt_params_args = (
    [
        (l_x_cmpnt_nrmlzd_edges_min, l_x_cmpnt_nrmlzd_edges_max, l_x_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_y_cmpnt_nrmlzd_edges_dim_vlnplt_params_args = (
    [
        (l_y_cmpnt_nrmlzd_edges_min, l_y_cmpnt_nrmlzd_edges_max, l_y_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_z_cmpnt_nrmlzd_edges_dim_vlnplt_params_args = (
    [
        (l_z_cmpnt_nrmlzd_edges_min, l_z_cmpnt_nrmlzd_edges_max, l_z_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_edges_dim_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_x_cmpnt_edges_dim_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_y_cmpnt_edges_dim_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_z_cmpnt_edges_dim_vlnplt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_nrmlzd_edges_dim_vlnplt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_x_cmpnt_nrmlzd_edges_dim_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_y_cmpnt_nrmlzd_edges_dim_vlnplt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_violinplot_plotter, l_z_cmpnt_nrmlzd_edges_dim_vlnplt_params_args)

# %%
# Plots displaying attributes of the statistical distribution of the
# core_pb and core_pb_conn edge length variants for each dimension
from heterogeneous_spatial_networks_worker import run_swidt_graph_l_edges_variant_dim_dist_stats_plotter

# For future cases, one may need to make multiple sets of such
# preformatting parameters, one for each variant and graph type
l_edges_min = 0.0
l_edges_max = 25.0
l_edges_inc = 5.0

l_x_cmpnt_edges_min = -l_edges_max
l_x_cmpnt_edges_max = l_edges_max
l_x_cmpnt_edges_inc = l_edges_inc

l_y_cmpnt_edges_min = -l_edges_max
l_y_cmpnt_edges_max = l_edges_max
l_y_cmpnt_edges_inc = l_edges_inc

l_z_cmpnt_edges_min = -l_edges_max
l_z_cmpnt_edges_max = l_edges_max
l_z_cmpnt_edges_inc = l_edges_inc

l_nrmlzd_edges_min = 0.0
l_nrmlzd_edges_max = 0.4
l_nrmlzd_edges_inc = 0.1

l_x_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_x_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_y_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_y_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc

l_z_cmpnt_nrmlzd_edges_min = -l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_max = l_nrmlzd_edges_max
l_z_cmpnt_nrmlzd_edges_inc = l_nrmlzd_edges_inc


dim_list = dim_arr.tolist()


l_edges_dim_dist_stats_plt_params_args = (
    [
        (l_edges_min, l_edges_max, l_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_edges)
        for dim in dim_list
    ]
)
l_x_cmpnt_edges_dim_dist_stats_plt_params_args = (
    [
        (l_x_cmpnt_edges_min, l_x_cmpnt_edges_max, l_x_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_edges)
        for dim in dim_list
    ]
)
l_y_cmpnt_edges_dim_dist_stats_plt_params_args = (
    [
        (l_y_cmpnt_edges_min, l_y_cmpnt_edges_max, l_y_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_edges)
        for dim in dim_list
    ]
)
l_z_cmpnt_edges_dim_dist_stats_plt_params_args = (
    [
        (l_z_cmpnt_edges_min, l_z_cmpnt_edges_max, l_z_cmpnt_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_edges)
        for dim in dim_list
    ]
)

l_nrmlzd_edges_dim_dist_stats_plt_params_args = (
    [
        (l_nrmlzd_edges_min, l_nrmlzd_edges_max, l_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_x_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args = (
    [
        (l_x_cmpnt_nrmlzd_edges_min, l_x_cmpnt_nrmlzd_edges_max, l_x_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_x_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_y_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args = (
    [
        (l_y_cmpnt_nrmlzd_edges_min, l_y_cmpnt_nrmlzd_edges_max, l_y_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_y_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)
l_z_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args = (
    [
        (l_z_cmpnt_nrmlzd_edges_min, l_z_cmpnt_nrmlzd_edges_max, l_z_cmpnt_nrmlzd_edges_inc, network, date, batch, int(dim), b, k_arr, eta_n_arr, n_arr, params_arr, config_arr, pruning_arr, elastically_effective, l_z_cmpnt_nrmlzd_edges)
        for dim in dim_list
    ]
)


__spec__ = None
with multiprocessing.Pool(processes=cpu_num) as pool:
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_edges_dim_dist_stats_plt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_x_cmpnt_edges_dim_dist_stats_plt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_y_cmpnt_edges_dim_dist_stats_plt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_z_cmpnt_edges_dim_dist_stats_plt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_nrmlzd_edges_dim_dist_stats_plt_params_args)
    pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_x_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_y_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args)
    # pool.map(run_swidt_graph_l_edges_variant_dim_dist_stats_plotter, l_z_cmpnt_nrmlzd_edges_dim_dist_stats_plt_params_args)
